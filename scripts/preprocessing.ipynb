# %%
import pandas as pd
from jeeves.preprocessing import rem_unicode, remove_digits, remove_punctuation, remove_stopwords

# %%
df = pd.read_table("cfp.tsv")

# %%
df.head()
# Out:
#                                                title  n_comments  year  \
# 0       Consuming Government Data with Python and D3           0  2015
# 1                     Don’t get scared, Get Started!           1  2015
# 2  Distributed scheduling leveraging multiple nod...           0  2015
# 3                  Analyzing Python code with Pylint           0  2015
# 4  Python 3 Metaprogramming, Macros, Madness & More!           0  2015
#
#                                   speaker_links  \
# 0  Talks:You can reach me at GitHub and Twitter
# 1              Tapasweni PathakShaifali Agrawal
# 2             http://glusterhacker.blogspot.in/
# 3     Pylint contributionsCPython contributions
# 4                                           NaN
#
#                                         content_urls  \
# 0                                                NaN
# 1                                                TBA
# 2  http://www.gluster.org/community/documentation...
# 3  The project pageBitbucket forgeDocumentationPr...
# 4  Github repository for the code that accompanie...
#
#                                         speaker_info target_audience  \
# 0  Pratap Vardhan is a Data Scientist at Gramener...    Intermediate
# 1  Tapasweni PathakI have done bachelors in IT fr...        Beginner
# 2  I am a software engineer at Red Hat Inc., work...        Beginner
# 3  I'm an open source enthusiast coming from Roma...    Intermediate
# 4  Suhas is a Data Scientist at Gramener, and was...    Intermediate
#
#                             section   type  last_updated  \
# 0  Data Visualization and Analytics  Talks  03 Sep, 2015
# 1                            Others  Talks  31 May, 2015
# 2                       Concurrency  Talks  27 Apr, 2015
# 3                            Others  Talks  21 Sep, 2015
# 4                       Core Python  Talks  03 Sep, 2015
#
#                                        prerequisites  \
# 0                                                NaN
# 1    Nothing.....other than your passion for coding.
# 2  A basic understanding of how a distributed sys...
# 3  The participants should have a basic understan...
# 4                                                NaN
#
#                                          description
# 0  The explosion of open data, especially governm...
# 1  Opensource world is full of excitement, knowle...
# 2  Setting up a cron job in a machine, is perhaps...
# 3  Given the dynamic nature of Python, some bugs ...
# 4  SummaryEver wanted to conquer the world, but j...

# %%
text_cols = "title speaker_info section target_audience type prerequisites description".split()
pipe = [rem_unicode, remove_digits, remove_punctuation, remove_stopwords, lambda x: x.lower()]
for col in text_cols:
    s = df.pop(col)
    for cleaner in pipe:
        s = s.astype(str).apply(cleaner)
    df[col] = s

# %%
df.head()
# Out:
#    n_comments  year                                 speaker_links  \
# 0           0  2015  Talks:You can reach me at GitHub and Twitter
# 1           1  2015              Tapasweni PathakShaifali Agrawal
# 2           0  2015             http://glusterhacker.blogspot.in/
# 3           0  2015     Pylint contributionsCPython contributions
# 4           0  2015                                           NaN
#
#                                         content_urls  last_updated  \
# 0                                                NaN  03 Sep, 2015
# 1                                                TBA  31 May, 2015
# 2  http://www.gluster.org/community/documentation...  27 Apr, 2015
# 3  The project pageBitbucket forgeDocumentationPr...  21 Sep, 2015
# 4  Github repository for the code that accompanie...  03 Sep, 2015
#
#                                                title  \
# 0                 consuming government data python d
# 1                        dont get scared get started
# 2  distributed scheduling leveraging multiple nod...
# 3                       analyzing python code pylint
# 4       python  metaprogramming macros madness  more
#
#                                         speaker_info  \
# 0  pratap vardhan data scientist gramenercom data...
# 1  tapasweni pathaki done bachelors it igdtuw i w...
# 2  i software engineer red hat inc working gluste...
# 3  im open source enthusiast coming romania lead ...
# 4  suhas data scientist gramener previously engin...
#
#                         section target_audience   type  \
# 0  data visualization analytics    intermediate  talks
# 1                        others        beginner  talks
# 2                   concurrency        beginner  talks
# 3                        others    intermediate  talks
# 4                   core python    intermediate  talks
#
#                                        prerequisites  \
# 0                                                nan
# 1                        nothingother passion coding
# 2  a basic understanding distributed system works...
# 3  the participants basic understanding python no...
# 4                                                nan
#
#                                          description
# 0  the explosion open data especially government ...
# 1  opensource world full excitement knowledge enc...
# 2  setting cron job machine perhaps easiest way s...
# 3  given dynamic nature python bugs tend creep co...
# 4  summaryever wanted conquer world fell short kn...

# %%
df['speaker_link_present'] = False
df['content_url_present'] = False

# %%
import numpy as np

# %%
for col in df:
    if df[col].dtype is np.dtype('O'):
        df[col].fillna(value="", inplace=True)

# %%
URL_PATTERN = "(http|ftp|https)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?"
df.loc[df.speaker_links.str.contains(URL_PATTERN, case=False), "speaker_link_present"] = True
df.loc[df.content_urls.str.contains(URL_PATTERN, case=False), "content_url_present"] = True
# Out:
# /Users/jaidevd/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   from ipykernel import kernelapp as app
# /Users/jaidevd/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()

# %%
df.content_url_present.sum() / float(df.shape[0])
# Out:
# 0.47241379310344828

# %%
del df['content_urls']
del df['speaker_links']

# %%
df['last_updated'] = pd.to_datetime(df.last_updated)

# %%
df.head()
# Out:
#    n_comments  year last_updated  \
# 0           0  2015   2015-09-03
# 1           1  2015   2015-05-31
# 2           0  2015   2015-04-27
# 3           0  2015   2015-09-21
# 4           0  2015   2015-09-03
#
#                                                title  \
# 0                 consuming government data python d
# 1                        dont get scared get started
# 2  distributed scheduling leveraging multiple nod...
# 3                       analyzing python code pylint
# 4       python  metaprogramming macros madness  more
#
#                                         speaker_info  \
# 0  pratap vardhan data scientist gramenercom data...
# 1  tapasweni pathaki done bachelors it igdtuw i w...
# 2  i software engineer red hat inc working gluste...
# 3  im open source enthusiast coming romania lead ...
# 4  suhas data scientist gramener previously engin...
#
#                         section target_audience   type  \
# 0  data visualization analytics    intermediate  talks
# 1                        others        beginner  talks
# 2                   concurrency        beginner  talks
# 3                        others    intermediate  talks
# 4                   core python    intermediate  talks
#
#                                        prerequisites  \
# 0                                                nan
# 1                        nothingother passion coding
# 2  a basic understanding distributed system works...
# 3  the participants basic understanding python no...
# 4                                                nan
#
#                                          description speaker_link_present  \
# 0  the explosion open data especially government ...                False
# 1  opensource world full excitement knowledge enc...                False
# 2  setting cron job machine perhaps easiest way s...                 True
# 3  given dynamic nature python bugs tend creep co...                False
# 4  summaryever wanted conquer world fell short kn...                False
#
#   content_url_present
# 0               False
# 1               False
# 2                True
# 3               False
# 4               False

# %%
deadline_16 = pd.to_datetime("1 July 2016")
deadline_15 = pd.to_datetime("1 June 2015")

# %%
df['deadlinediff'] = 0
df.loc[df.year == 2015, "deadlinediff"] = deadline_15 - df[df.year == 2015]['last_updated']
df.loc[df.year == 2016, "deadlinediff"] = deadline_16 - df[df.year == 2016]['last_updated']

# %%
del df['last_updated']

# %%
df.head()
# Out:
#    n_comments  year                                              title  \
# 0           0  2015                 consuming government data python d
# 1           1  2015                        dont get scared get started
# 2           0  2015  distributed scheduling leveraging multiple nod...
# 3           0  2015                       analyzing python code pylint
# 4           0  2015       python  metaprogramming macros madness  more
#
#                                         speaker_info  \
# 0  pratap vardhan data scientist gramenercom data...
# 1  tapasweni pathaki done bachelors it igdtuw i w...
# 2  i software engineer red hat inc working gluste...
# 3  im open source enthusiast coming romania lead ...
# 4  suhas data scientist gramener previously engin...
#
#                         section target_audience   type  \
# 0  data visualization analytics    intermediate  talks
# 1                        others        beginner  talks
# 2                   concurrency        beginner  talks
# 3                        others    intermediate  talks
# 4                   core python    intermediate  talks
#
#                                        prerequisites  \
# 0                                                nan
# 1                        nothingother passion coding
# 2  a basic understanding distributed system works...
# 3  the participants basic understanding python no...
# 4                                                nan
#
#                                          description speaker_link_present  \
# 0  the explosion open data especially government ...                False
# 1  opensource world full excitement knowledge enc...                False
# 2  setting cron job machine perhaps easiest way s...                 True
# 3  given dynamic nature python bugs tend creep co...                False
# 4  summaryever wanted conquer world fell short kn...                False
#
#   content_url_present  deadlinediff
# 0               False      -94 days
# 1               False        1 days
# 2                True       35 days
# 3               False     -112 days
# 4               False      -94 days

# %%
df.deadlinediff.min()
# Out:
# Timedelta('-370 days +00:00:00')

# %%
df['deadlinediff'] = df.deadlinediff.apply(lambda x: x.days)

# %%
df.head()
# Out:
#    n_comments  year                                              title  \
# 0           0  2015                 consuming government data python d
# 1           1  2015                        dont get scared get started
# 2           0  2015  distributed scheduling leveraging multiple nod...
# 3           0  2015                       analyzing python code pylint
# 4           0  2015       python  metaprogramming macros madness  more
#
#                                         speaker_info  \
# 0  pratap vardhan data scientist gramenercom data...
# 1  tapasweni pathaki done bachelors it igdtuw i w...
# 2  i software engineer red hat inc working gluste...
# 3  im open source enthusiast coming romania lead ...
# 4  suhas data scientist gramener previously engin...
#
#                         section target_audience   type  \
# 0  data visualization analytics    intermediate  talks
# 1                        others        beginner  talks
# 2                   concurrency        beginner  talks
# 3                        others    intermediate  talks
# 4                   core python    intermediate  talks
#
#                                        prerequisites  \
# 0                                                nan
# 1                        nothingother passion coding
# 2  a basic understanding distributed system works...
# 3  the participants basic understanding python no...
# 4                                                nan
#
#                                          description speaker_link_present  \
# 0  the explosion open data especially government ...                False
# 1  opensource world full excitement knowledge enc...                False
# 2  setting cron job machine perhaps easiest way s...                 True
# 3  given dynamic nature python bugs tend creep co...                False
# 4  summaryever wanted conquer world fell short kn...                False
#
#   content_url_present  deadlinediff
# 0               False           -94
# 1               False             1
# 2                True            35
# 3               False          -112
# 4               False           -94

# %%
sel_2015 = """
        simple hacks to make your django website faster
        pretty printing in python
        machine learning techniques for building a large scale
        laying out your django projects
        python and riakdb
        building flexible filesystems with fuse-python
        symengine: the future fast core of computer algebra systems
        test driven development with ansible
        explore big data using simple python code
        introduction to nipype and how do we create
        python load balancer: 0 to 1 million requests per second
        creating, deployment & customizing
        building nextgen iot solutions
        consuming government data with python and d3
        python traceback for humans
        how to build microservices using zeromq and wsgi
        rip nagios. hello docker shinken
        building offensive web security framework in python
        how to detect phishing urls using pyspark decision trees
        fedmsg: the message bus of fedora infrastructure
        concurrent data processing in python
        analyzing arguments during a debate using natural language processing
        avoiding common pitfalls of datetime from a webapp
        python 2 metaprogramming, macros, madness & more
        rest apis - what, why and how
        solving logical puzzles with natural language processing
        getting started with ansible
        let's learn statistics
        using devstack to contribute to openstack
        building nextgen iot solutions using python and cloud
        reasoning under uncertainty with python
        python on your mobile phone(advanced concepts)
        django projects the right way
        symbolic computation with python, sympy
        thinking in functions
        """

sel_2016 = """
        building a scalable nba sports analytics platform using python data stack
        hacking the python ast
        helix and salt: case study in high volume and distributed python applications
        realtime microservices with server side flux
        building an automatic keyphrase extraction system using nltk
        testing native binaries using cffi and py.test
        the trends in choosing licenses in python ecosystems
        good bye, call stack; hello, event driven architectures
        algorithmic music generation
        python byte code hacks
        load testing using locust.io
        continuous integration for data scientists
        building companion chatbot with python
        deploying your python backend with
        big data analysis using pyspark
        flying a drone
        containerize upstream projects effortlessly
        financial modelling and simulation with python
        micropython - porting python to microcontrollers
        creating a recommendation engine based on nlp and contextual
        open source health monitoring and evaluation systems
        concurrency in modern robots
        building a secure iot platform using paho and flask
        don't write tests, generate them
        real time sentiment analysis with apache storm and python
        building a lie detector: multi-modal sentiment analysis
        docker workshop
        talking to machines: optimizing neural networks with theano
        productive coding with pycharm
        demystifying the django rest framework
        scaling django with kubernetes
        """

sel_2015 = [l.rstrip().lstrip() for l in sel_2015.splitlines() if l]
sel_2016 = [l.rstrip().lstrip() for l in sel_2016.splitlines() if l]

# %%
df['selected'] = False

# %%
sel_2015 = [l for l in sel_2015 if l]
sel_2016 = [l for l in sel_2016 if l]

# %%
for proposal in sel_2015:
    proposal = remove_stopwords(proposal)
    proposal = remove_punctuation(proposal)
    sdf = df[df.year == 2015][df.title.str.contains(proposal, case=False)]
    if sdf.shape[0] != 1:
        print "2015", proposal
    else:
        df.loc[sdf.index[0], "selected"] = True
for proposal in sel_2016:
    proposal = remove_stopwords(proposal)
    proposal = remove_punctuation(proposal)
    sdf = df[df.year == 2016][df.title.str.contains(proposal, case=False)]
    if sdf.shape[0] != 1:
        print "2016", proposal
    else:
        df.loc[sdf.index[0], "selected"] = True
# Out:
# 2015 simple hacks make django website faster
# 2015 python riakdb
# 2015 symengine future fast core computer algebra systems
# 2015 python load balancer 0 1 million requests per second
# 2015
# /Users/jaidevd/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/jaidevd/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#  consuming government data python d3
# 2015 python traceback humans
# 2015 fedmsg message bus fedora infrastructure
# 2015 python 2 metaprogramming macros madness
# 2016 building scalable nba sports analytics platform using python data stack
# 2016 trends choosing licenses python ecosystems
# 2016 flying drone
# 2016 talking machines optimizing neural networks theano

# %%
df[df.year == 2016][df.title.str.contains("talking.*machines")]
# Out:
# /Users/jaidevd/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#      n_comments  year                                              title  \
# 213           0  2016  talking machines  optimizing neural networks t...
#
#                                           speaker_info               section  \
# 213  deep learning robotics enthusiast presently fi...  scientific computing
#
#     target_audience       type  \
# 213    intermediate  workshops
#
#                                          prerequisites  \
# 213  while topics introduced talk scratch familiari...
#
#                                            description speaker_link_present  \
# 213  with recent advances field deep learning compu...                False
#
#     content_url_present  deadlinediff selected
# 213               False           -27    False

# %%
df.loc[213, "selected"] = True

# %%
df.head()
# Out:
#    n_comments  year                                              title  \
# 0           0  2015                 consuming government data python d
# 1           1  2015                        dont get scared get started
# 2           0  2015  distributed scheduling leveraging multiple nod...
# 3           0  2015                       analyzing python code pylint
# 4           0  2015       python  metaprogramming macros madness  more
#
#                                         speaker_info  \
# 0  pratap vardhan data scientist gramenercom data...
# 1  tapasweni pathaki done bachelors it igdtuw i w...
# 2  i software engineer red hat inc working gluste...
# 3  im open source enthusiast coming romania lead ...
# 4  suhas data scientist gramener previously engin...
#
#                         section target_audience   type  \
# 0  data visualization analytics    intermediate  talks
# 1                        others        beginner  talks
# 2                   concurrency        beginner  talks
# 3                        others    intermediate  talks
# 4                   core python    intermediate  talks
#
#                                        prerequisites  \
# 0                                                nan
# 1                        nothingother passion coding
# 2  a basic understanding distributed system works...
# 3  the participants basic understanding python no...
# 4                                                nan
#
#                                          description speaker_link_present  \
# 0  the explosion open data especially government ...                False
# 1  opensource world full excitement knowledge enc...                False
# 2  setting cron job machine perhaps easiest way s...                 True
# 3  given dynamic nature python bugs tend creep co...                False
# 4  summaryever wanted conquer world fell short kn...                False
#
#   content_url_present  deadlinediff selected
# 0               False           -94     True
# 1               False             1    False
# 2                True            35    False
# 3               False          -112    False
# 4               False           -94     True

# %%
df.to_csv("tagged.csv", index=False, sep="\t")
